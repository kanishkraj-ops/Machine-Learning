# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkraj-ops/Machine-Learning/blob/main/MATPLOTLIB_Plotting_and_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRO TO MATPLOTLIB**

# %%
# %matplotlib inline #we can see the plots in our notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot();
#add a semicolon after this command so that you dont get the object
# reference in sqaure brackets , you can ignore it if you like the other way

# %%
x = [1,2,3,4]
y = [4,5,6,7]
plt.plot(x,y);

# %%
#1st method
fig = plt.figure() #creates a figure that is the a blank canvas
ax = fig.add_subplot() #creates a drawing area an axes to the canvas
ax.plot(x,y);

# %%
#2nd method(recommended)
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
#3rd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y);
