# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkraj-ops/Machine-Learning/blob/main/MATPLOTLIB_Plotting_and_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRO TO MATPLOTLIB**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use('seaborn-v0_8')

# %%
plt.plot();
#add a semicolon after this command so that you dont get the object
# reference in sqaure brackets , you can ignore it if you like the other way

# %%
x = [1,2,3,4]
y = [4,5,6,7]
plt.plot(x,y);

# %%
#1st method
fig = plt.figure() #creates a figure that is the a blank canvas
ax = fig.add_subplot() #creates a drawing area an axes to the canvas
ax.plot(x,y);

# %%
#2nd method(recommended)
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
#3rd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y);

# %% [markdown]
# ![matplotlib-anatomy-of-a-plot.png](data:image/png;base64,...)

# %%
#step-1
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#step-2
x=[1,2,3,4]
y=[10,35,33,67]

#step-3
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(x,y)

#step-4
ax.set(title="Example plot",
       xlabel = 'x-axis',
       ylabel = 'y-axis')
#step-5
fig.savefig("plot.png")

# %% [markdown]
# # **DIFFERNT KINDS OF PLOTS**
#
#
# *   HISTOGRAM
# *   SCATTER PLOT
# *   BAR PLOT
# *   SUBPLOTS
# *   LINE PLOTS

# %%
import numpy as np

# %%
#create some data
x = np.linspace(0,10,1000)
y = x**2

# %%
fig, ax = plt.subplots()
ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.scatter(x,y)

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.log10(x));
# Out:
# /tmp/ipython-input-339-3937086385.py:2: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(x,np.log10(x));

# %%
#Make plot from dictionary
car_prices = {
    "BMW":10000,
    "AUDI" :35004,
    "MERCEDES":33440,
}
fig, ax = plt.subplots()
ax.bar(car_prices.keys(),car_prices.values());
ax.set(title='Car Dealership sales',
       xlabel = 'Car',
       ylabel='Price($)');

# %%
fig,ax = plt.subplots()
ax.barh(list(car_prices.keys()),list(car_prices.values()));

# %%
#subplots
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax1.plot(x,y)
ax2.scatter(x,y)
ax3.bar(car_prices.keys(),car_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# ##**PLOTTING FROM PANDAS DATAFRAME**

# %%
car_sales = pd.read_csv("sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[$\,\.]" , "" ,regex=True)
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'] = car_sales['Price']/100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["sale_date"] = pd.date_range("2021-01-01",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  sale_date
# 0  Toyota  White         150043      4   4000.0 2021-01-01
# 1   Honda    Red          87899      4   5000.0 2021-01-02
# 2  Toyota   Blue          32549      3   7000.0 2021-01-03
# 3     BMW  Black          11179      5  22000.0 2021-01-04
# 4  Nissan  White         213095      4   3500.0 2021-01-05
# 5  Toyota  Green          99213      4   4500.0 2021-01-06
# 6   Honda   Blue          45698      4   7500.0 2021-01-07
# 7   Honda   Blue          54738      4   7000.0 2021-01-08
# 8  Toyota  White          60000      4   6250.0 2021-01-09
# 9  Nissan  White          31600      4   9700.0 2021-01-10

# %%
car_sales["Total_sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  sale_date  Total_sales
# 0  Toyota  White         150043      4   4000.0 2021-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2021-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2021-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2021-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2021-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2021-01-10      76450.0

# %%
car_sales.plot(x="sale_date",y="Total_sales");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
x = np.random.rand(10,4)
x

df  = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.923457  0.922774  0.751761  0.222821
# 1  0.020630  0.621694  0.818594  0.568846
# 2  0.650676  0.260662  0.549599  0.731054
# 3  0.423696  0.313102  0.353221  0.029666
# 4  0.904849  0.079088  0.654900  0.629550
# 5  0.876095  0.128094  0.698671  0.997621
# 6  0.595667  0.495328  0.721789  0.878506
# 7  0.758747  0.460924  0.741943  0.108842
# 8  0.348543  0.696259  0.059946  0.000808
# 9  0.950320  0.313081  0.408626  0.134199

# %%
df.plot.bar(); #or df.plot(kind="bar")

# %%
car_sales.plot(x="Make",y="Price",kind="bar");

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease.plot()
# Out:
# <Axes: >

# %%
heart_disease.plot.hist(subplots=True, figsize=(5,15));

# %%
over_50 = heart_disease[heart_disease['age']>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(x='age',
             y='chol',
             c='target',
             kind='scatter',
             cmap="winter");

# %%
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax = ax,
             cmap="winter"
            );

# %%
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50["age"],y=over_50['chol'],c=over_50['target'],cmap="summer")
ax.set(title='Heart Disease and Cholestrol Levels',xlabel='Age',ylabel='Cholestrol');
#add a legend or you can say scale

ax.legend(*scatter.legend_elements(),title='Target');
#add a horizontal line
ax.axhline(over_50['chol'].mean(),color='red',linestyle='--');

# %%
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50["chol"],y=over_50['thalach'],c=over_50['target'],cmap="summer");
ax.set(title='Heart Disease and Cholestrol Levels',xlabel='Cholestrol',ylabel='Heart-Rate');
#add a legend or you can say scale

ax.legend(*scatter.legend_elements(),title='Target');
#add a horizontal line
ax.axhline(over_50['thalach'].mean(),color='red',linestyle='--');

# %%
fig, (ax0,ax1) = plt.subplots(ncols=1,nrows=2,figsize=(10,10))

#add data to ax0
scatter = ax0.scatter(x=over_50["chol"],y=over_50['thalach'],c=over_50['target'],cmap="summer");
ax0.set(title='Heart Disease and Cholestrol Levels',xlabel='Cholestrol',ylabel='Heart-Rate');
#add a legend or you can say scale

ax0.legend(*scatter.legend_elements(),title='Target');
ax0.axhline(y=over_50['thalach'].mean(),color='red',linestyle='--');



#add data to ax1

scatter = ax1.scatter(x=over_50["age"],y=over_50['thalach'],c=over_50['target'],cmap="winter");
ax1.set(title='Heart Disease and Cholestrol Levels',xlabel='Age',ylabel='Heart-Rate');
#add a legend or you can say scale

ax1.legend(*scatter.legend_elements(),title='Target');
#add a horizontal line
ax1.axhline(over_50['thalach'].mean(),color='red',linestyle='--');
fig.suptitle('Heart Disease Analysis',fontweight='bold');

# %% [markdown]
# # **CUSTOMIZING YOUR PLOTS**

# %%
plt.style.available
#plt.style.use('available styles')
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
